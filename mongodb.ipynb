# %%
import pymongo
from pymongo import MongoClient 
import dns
import sys
print(sys.executable)
# Out:
# d:\Pooja\project\sensorlive\venv\Scripts\python.exe

# %%
connection_string="mongodb+srv://pooja980900_db_user:POoja0902@cluster0.ms3o5qa.mongodb.net/?appName=Cluster0"

# %%
client = MongoClient(connection_string)

# %%
db=client["liveclass"]

# %%
collection=db["mongoclass"]

# %%
data={
    "name":"pooja patel",
    "age":22,
    "email":"pooja980900@gmail.com"
}

# %%
collection.insert_one(data)

# %%
cursor=collection.find({})
for i in cursor:
    print(i)
# Out:
# {'_id': ObjectId('695b522ec994224262650a07'), 'name': 'pooja patel', 'age': 22, 'email': 'pooja980900@gmail.com'}
